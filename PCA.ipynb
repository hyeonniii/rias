# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv("/content/drive/MyDrive/Documents/지현연구/응통논문/tripadvisor_review.csv")

# %%
data.head()
# Out:
#   User ID  Category 1  Category 2  ...  Category 8  Category 9  Category 10
# 0  User 1        0.93         1.8  ...        2.79        1.82         2.42
# 1  User 2        1.02         2.2  ...        2.63        1.86         2.32
# 2  User 3        1.22         0.8  ...        2.80        1.31         2.50
# 3  User 4        0.45         1.8  ...        2.96        1.57         2.86
# 4  User 5        0.51         1.2  ...        2.78        1.18         2.54
#
# [5 rows x 11 columns]

# %%
from sklearn import preprocessing

# %%
matrix=data.iloc[:,1:11]

# %%
matrix.head()
# Out:
#    Category 1  Category 2  Category 3  ...  Category 8  Category 9  Category 10
# 0        0.93         1.8        2.29  ...        2.79        1.82         2.42
# 1        1.02         2.2        2.66  ...        2.63        1.86         2.32
# 2        1.22         0.8        0.54  ...        2.80        1.31         2.50
# 3        0.45         1.8        0.29  ...        2.96        1.57         2.86
# 4        0.51         1.2        1.18  ...        2.78        1.18         2.54
#
# [5 rows x 10 columns]

# %%
corrMat=matrix.corr()

# %%
print(np.linalg.eig(corrMat))
# Out:
# (array([2.97750441, 0.14100309, 0.3288842 , 0.45998868, 0.70445466,
#        0.80798164, 1.26279397, 1.23309929, 1.01981966, 1.0644704 ]), array([[ 0.01533238, -0.00994215, -0.25060928,  0.03987369,  0.198421  ,
#          0.5033068 ,  0.31907527, -0.520473  , -0.31367748,  0.41411084],
#        [-0.12965685, -0.06066258, -0.12293371,  0.05571957,  0.5981332 ,
#          0.343452  , -0.29722301,  0.60320577, -0.03662148,  0.1789674 ],
#        [-0.42881276, -0.51101316,  0.1247714 , -0.52180303,  0.11411554,
#          0.19608956,  0.28305662, -0.04607173,  0.129529  , -0.34153182],
#        [-0.22864226, -0.01366018,  0.09221006, -0.42824895, -0.03694906,
#         -0.43167726,  0.01897704,  0.07877379,  0.0224208 ,  0.74890429],
#        [-0.32181751,  0.08971705, -0.5369171 , -0.23045888, -0.21610398,
#         -0.11798417, -0.34565736, -0.00791693, -0.56644367, -0.21441024],
#        [-0.41744888, -0.00793526,  0.69220114,  0.29880387,  0.00143914,
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(random_state=1107)
X_p = pca.fit_transform(matrix)

pd.Series(np.cumsum(pca.explained_variance_ratio_))
# Out:
# 0    0.425201
# 1    0.602432
# 2    0.726965
# 3    0.800151
# 4    0.869498
# 5    0.923299
# 6    0.964596
# 7    0.990469
# 8    0.999992
# 9    1.000000
# dtype: float64

# %%
pca = PCA(n_components=4)

# %%
pcadata = pca.fit_transform(matrix)

# %%
principalDf = pd.DataFrame(data = pcadata, columns = ['comp1', 'comp2','comp3','comp4'])

# %%
principalDf
# Out:
#         comp1     comp2     comp3     comp4
# 0    1.391408 -0.063253  0.400050  0.429629
# 1    2.225649  0.660561  0.425392  0.295556
# 2   -0.677268 -0.512645 -0.413726  0.075759
# 3   -0.849739  0.132922  0.591990  0.045847
# 4    0.420059  0.202708 -0.200443 -0.528396
# ..        ...       ...       ...       ...
# 975 -0.896969 -0.188086 -0.097788 -0.639164
# 976 -0.050651 -0.462573 -0.372721 -0.111892
# 977 -0.273185  0.210821 -0.052019 -0.431124
# 978 -1.507841 -1.248347 -0.590303 -0.170839
# 979  0.436563  0.119134 -0.953343 -0.209352
#
# [980 rows x 4 columns]

# %%
principalDf.to_csv("pcadata4.csv",mode='w')
