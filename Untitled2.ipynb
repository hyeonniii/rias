# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv("/content/drive/MyDrive/Documents/지현연구/응통논문/tripadvisor_review.csv")

# %%
data.head()
# Out:
#   User ID  Category 1  Category 2  ...  Category 8  Category 9  Category 10
# 0  User 1        0.93         1.8  ...        2.79        1.82         2.42
# 1  User 2        1.02         2.2  ...        2.63        1.86         2.32
# 2  User 3        1.22         0.8  ...        2.80        1.31         2.50
# 3  User 4        0.45         1.8  ...        2.96        1.57         2.86
# 4  User 5        0.51         1.2  ...        2.78        1.18         2.54
#
# [5 rows x 11 columns]

# %%
data.shape
# Out:
# (980, 11)

# %%
from sklearn.cluster import KMeans
from sklearn import preprocessing

# %%
processed_data=data.iloc[:,1:11]

# %%
distortions = []
K= range(1,10)
for k in K:
  kmeanModel= KMeans(n_clusters=k)
  kmeanModel.fit(data.iloc[:,1:9])
  distortions.append(kmeanModel.inertia_)

# %%
plt.figure(figsize=(16,8))
plt.plot(K,distortions,'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.show()

# %%
kmeanModel=KMeans(n_clusters=3)
kmeanModel.fit(data.iloc[:,1:9])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
result_by_sklearn = data.iloc[:,1:9]
result_by_sklearn["cluster"]=kmeanModel.labels_
result_by_sklearn.head()
# Out:
#    Category 1  Category 2  Category 3  ...  Category 7  Category 8  cluster
# 0        0.93         1.8        2.29  ...        3.19        2.79        1
# 1        1.02         2.2        2.66  ...        3.21        2.63        1
# 2        1.22         0.8        0.54  ...        3.18        2.80        0
# 3        0.45         1.8        0.29  ...        3.18        2.96        0
# 4        0.51         1.2        1.18  ...        3.18        2.78        2
#
# [5 rows x 9 columns]

# %%
result_by_sklearn
# Out:
#      Category 1  Category 2  Category 3  ...  Category 7  Category 8  cluster
# 0          0.93        1.80        2.29  ...        3.19        2.79        1
# 1          1.02        2.20        2.66  ...        3.21        2.63        1
# 2          1.22        0.80        0.54  ...        3.18        2.80        0
# 3          0.45        1.80        0.29  ...        3.18        2.96        0
# 4          0.51        1.20        1.18  ...        3.18        2.78        2
# ..          ...         ...         ...  ...         ...         ...      ...
# 975        0.74        1.12        0.30  ...        3.17        2.78        0
# 976        1.25        0.92        1.12  ...        3.18        2.79        0
# 977        0.61        1.32        0.67  ...        3.17        2.81        2
# 978        0.93        0.20        0.13  ...        3.18        2.98        0
# 979        0.93        0.56        1.13  ...        3.18        2.87        2
#
# [980 rows x 9 columns]

# %%
corrMat=processed_data.corr()

# %%
corrMat
# Out:
#              Category 1  Category 2  ...  Category 9  Category 10
# Category 1     1.000000   -0.187692  ...   -0.047313     0.050700
# Category 2    -0.187692    1.000000  ...    0.073342    -0.065762
# Category 3     0.008613    0.043586  ...   -0.085435    -0.440543
# Category 4     0.073456    0.131624  ...    0.026670    -0.352909
# Category 5    -0.100483    0.119631  ...    0.041693    -0.247470
# Category 6     0.094142    0.148404  ...    0.096410    -0.438104
# Category 7    -0.012474    0.110052  ...    0.084965    -0.710731
# Category 8     0.020029   -0.158642  ...    0.169695     0.114701
# Category 9    -0.047313    0.073342  ...    1.000000    -0.045682
# Category 10    0.050700   -0.065762  ...   -0.045682     1.000000
#
# [10 rows x 10 columns]
